# %%
myList = list()

# %%
myList.append(10)

# %%
myList.append(20)

# %%
myList
# Out:
# [10, 20]

# %%
myList.append(30)

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList.pop()
# Out:
# 30

# %%
myList
# Out:
# [10, 20]

# %%
myList.pop()
# Out:
# 20

# %%
myList
# Out:
# [10]

# %%
from queue import LifoQueue
