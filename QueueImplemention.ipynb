# %%
'''
Queue()

enqueue(element)
dequeue
size()
isEmpty()
'''
# Out:
# '\nQueue()\n\nenqueue(element)\ndequeue\nsize()\nisEmpty()\n'

# %%
class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, element):
        self.items.append(element)  

    def dequeue(self):
        if self.isEmpty():
            return "Queue boş!"
        return self.items.pop(0)  

    def size(self):
        return len(self.items)  

    def isEmpty(self):
        return len(self.items) == 0

# %%
q = Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

# %%
print("Dequeue:", q.dequeue())  # 10
print("Boyut:", q.size())      # 2
print("Boş mu:", q.isEmpty())  # False
# Out:
# Dequeue: 10
# Boyut: 2
# Boş mu: False
