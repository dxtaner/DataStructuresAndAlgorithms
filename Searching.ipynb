# %%
class SearchingAlgorithms:
    
    def sequantialSearchUnordered(self, unorderedList, number):
        print("=== Unordered Sequential Search Başladı ===")
        
        ix = 0
        found = False
        
        while ix < len(unorderedList) and not found:
            print(f"Adım {ix}: Eleman = {unorderedList[ix]}")
            
            if unorderedList[ix] == number:
                print("Bulundu!")
                found = True
            else:
                print("Eşleşmedi, devam...")
                ix += 1
                
        print("Sonuç:", found)
        return found
    

    def sequantialSearchOrdered(self, orderedList, number):
        print("\n=== Ordered Sequential Search Başladı ===")
        
        ix = 0
        found = False
        tooBig = False
        
        while ix < len(orderedList) and not found and not tooBig:
            print(f"Adım {ix}: Eleman = {orderedList[ix]}")
            
            if orderedList[ix] == number:
                print("Bulundu!")
                found = True
            else:
                if orderedList[ix] > number:
                    print("Daha büyük değer geldi → durduruldu")
                    tooBig = True
                else:
                    print("➡️ Devam...")
                    ix += 1
        
        print("Sonuç:", found)
        return found
    

    def binarySearch(self, orderedList, number):
        print("\n=== Binary Search Başladı ===")
        
        firstPointer = 0
        lastPointer = len(orderedList) - 1
        found = False
        step = 1
        
        while firstPointer <= lastPointer and not found:
            midPoint = (firstPointer + lastPointer) // 2
            
            print(f"\nAdım {step}")
            print(f"First: {firstPointer}, Last: {lastPointer}, Mid: {midPoint}")
            print(f"Ortadaki Değer: {orderedList[midPoint]}")
            
            if orderedList[midPoint] == number:
                print("Bulundu!")
                found = True
            else:
                if number < orderedList[midPoint]:
                    print("⬅️ Sola git")
                    lastPointer = midPoint - 1
                else:
                    print("➡️ Sağa git")
                    firstPointer = midPoint + 1
            
            step += 1
        
        print("Sonuç:", found)
        return found

# %%
search = SearchingAlgorithms()

myList = [40,20,10,4,5,19,80,2,0,14]

# Unordered
search.sequantialSearchUnordered(myList, 10)
search.sequantialSearchUnordered(myList, 15)

# Sıralama
myList.sort()

# Ordered
search.sequantialSearchOrdered(myList, 10)
search.sequantialSearchOrdered(myList, 15)

# Binary
search.binarySearch(myList, 10)
search.binarySearch(myList, 15)
# Out:
# === Unordered Sequential Search Başladı ===
# Adım 0: Eleman = 40
# Eşleşmedi, devam...
# Adım 1: Eleman = 20
# Eşleşmedi, devam...
# Adım 2: Eleman = 10
# Bulundu!
# Sonuç: True
# === Unordered Sequential Search Başladı ===
# Adım 0: Eleman = 40
# Eşleşmedi, devam...
# Adım 1: Eleman = 20
# Eşleşmedi, devam...
# Adım 2: Eleman = 10
# Eşleşmedi, devam...
# Adım 3: Eleman = 4
# Eşleşmedi, devam...
# Adım 4: Eleman = 5
# Eşleşmedi, devam...
# Adım 5: Eleman = 19
# Eşleşmedi, devam...
# Adım 6: Eleman = 80
# Eşleşmedi, devam...
# Adım 7: Eleman = 2
# Eşleşmedi, devam...
# Adım 8: Eleman = 0
# Eşleşmedi, devam...
# Adım 9: Eleman = 14
# Eşleşmedi, devam...
# Sonuç: False
#
# === Ordered Sequential Search Başladı ===
# Adım 0: Eleman = 0
# ➡️ Devam...
# Adım 1: Eleman = 2
# ➡️ Devam...
# Adım 2: Eleman = 4
# ➡️ Devam...
# Adım 3: Eleman = 5
# ➡️ Devam...
# Adım 4: Eleman = 10
# Bulundu!
# Sonuç: True
#
# === Ordered Sequential Search Başladı ===
# Adım 0: Eleman = 0
# ➡️ Devam...
# Adım 1: Eleman = 2
# ➡️ Devam...
# Adım 2: Eleman = 4
# ➡️ Devam...
# Adım 3: Eleman = 5
# ➡️ Devam...
# Adım 4: Eleman = 10
# ➡️ Devam...
# Adım 5: Eleman = 14
# ➡️ Devam...
# Adım 6: Eleman = 19
# Daha büyük değer geldi → durduruldu
# Sonuç: False
#
# === Binary Search Başladı ===
#
# Adım 1
# First: 0, Last: 9, Mid: 4
# Ortadaki Değer: 10
# Bulundu!
# Sonuç: True
#
# === Binary Search Başladı ===
#
# Adım 1
# First: 0, Last: 9, Mid: 4
# Ortadaki Değer: 10
# ➡️ Sağa git
#
# Adım 2
# First: 5, Last: 9, Mid: 7
# Ortadaki Değer: 20
# ⬅️ Sola git
#
# Adım 3
# First: 5, Last: 6, Mid: 5
# Ortadaki Değer: 14
# ➡️ Sağa git
#
# Adım 4
# First: 6, Last: 6, Mid: 6
# Ortadaki Değer: 19
# ⬅️ Sola git
# Sonuç: False
# False
